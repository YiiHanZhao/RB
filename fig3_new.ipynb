# %%
import omicverse as ov
import scanpy as sc
import matplotlib
import matplotlib.pyplot as plt
import gc
import os

# %%
# %matplotlib inline
import omicverse as ov
ov.utils.ov_plot_set()
# Out:
# Dependency error: (numpy 1.26.4 (/mnt/home/yihanzhao/miniconda3/envs/zyh/lib/python3.10/site-packages), Requirement.parse('numpy<1.24,>=1.22'))

# %%
import scvi

# %%
scvi.model.utils
# Out:
# <module 'scvi.model.utils' from '/mnt/home/yihanzhao/miniconda3/envs/zyh/lib/python3.10/site-packages/scvi/model/utils/__init__.py'>

# %%
pathway_dict=ov.utils.geneset_prepare('/mnt/home/zehuazeng/analysis/placenta/genesets/WikiPathway_2021_Human.txt',organism='Human')

# %%
import shutil

# %%
# 源文件路径
src_path = '/mnt/home/zehuazeng/analysis/placenta/genesets/WikiPathway_2021_Human.txt'
# 目标文件路径
dest_path = '/mnt/home/yihanzhao/RB/WikiPathway_2021_Human.txt'

# 使用shutil.copyfile进行文件复制
shutil.copyfile(src_path, dest_path)

print("文件复制成功")
# Out:
# 文件复制成功

# %% [markdown]
# ## scbasset

# %%
! wget https://dp-lab-data-public.s3.amazonaws.com/SEACells-multiome/pwm_ad.h5ad -O /mnt/home/yihanzhao/RB/data/pwm_ad.h5ad

# %%
pwm = sc.read('/mnt/home/yihanzhao/RB/data/pwm_ad.h5ad')
pwm
# Out:
# AnnData object with n_obs × n_vars = 246113 × 729

# %%
rna=sc.read_h5ad('/mnt/home/yihanzhao/RB/data_new/rna_rb_pair_zhushi.h5ad')
rna
# Out:
# AnnData object with n_obs × n_vars = 729 × 16801
#     obs: 'tissue', 'domain', 'sample', 'nUMIs', 'mito_perc', 'detected_genes', 'cell_complexity', 'doublet_score', 'predicted_doublet', 'passing_mt', 'passing_nUMIs', 'passing_ngenes', 'n_genes', 'leiden', 'celltype', 'balancing_weight'
#     var: 'feature_types', 'mt', 'n_cells', 'percent_cells', 'robust', 'mean', 'var', 'residual_variances', 'highly_variable_features', 'chrom', 'chromStart', 'chromEnd', 'name', 'score', 'strand', 'thickStart', 'thickEnd', 'itemRgb', 'blockCount', 'blockSizes', 'blockStarts', 'gene_id', 'gene_type', 'dell', 'highly_variable'
#     uns: 'celltype_colors'
#     obsm: 'X_glue', 'X_mde_pca', 'X_mde_scVI', 'X_scVI', 'X_umap', 'scaled|original|X_pca'
#     varm: 'scaled|original|pca_loadings'
#     layers: 'counts', 'lognorm', 'scaled'

# %%
# Filter PWM to TFs present in dataset
has_expr = [g in rna.var_names for g in pwm.var_names]
frac = sum(has_expr) / len(has_expr)
print(f"{frac:.2%} ({sum(has_expr)}) TFs have expresssion")

pwm = pwm[:, has_expr]
# Out:
# 70.78% (516) TFs have expresssion

# %%
# 获取 'var' 的索引，这可能是基因或染色体等信息
var_index = pwm.var.index

# 将索引保存为 CSV 文件
var_index.to_frame(index=True, name='tf').to_csv('/mnt/home/yihanzhao/RB/data_new/var_index.csv', index_label='Index')

# %%
atac=sc.read_h5ad('/mnt/home/yihanzhao/RB/data_new/atac_rb_pair_zhushi.h5ad')
atac
# Out:
# AnnData object with n_obs × n_vars = 729 × 150000
#     obs: 'sample', 'tissue', 'domain', 'week', 'balancing_weight', 'celltype'
#     var: 'chrom', 'chromStart', 'chromEnd', 'highly_variable'
#     uns: 'celltype_colors'
#     obsm: 'X_glue', 'X_lsi', 'X_mde_lsi', 'X_umap'

# %%
atac.obsm["X_mde_scglue"] = ov.utils.mde(atac.obsm["X_glue"])

# %%
ov.utils.embedding(atac,
                basis='X_mde_lsi',frameon='small',palette=ov.utils.orange_color[5:6]+ov.utils.orange_color[0:1]+ov.utils.orange_color[7:8]+ov.utils.orange_color[9:10]+ov.utils.orange_color[6:7]+ov.utils.red_color[1:2]+ov.utils.red_color[3:4]+ov.utils.red_color[2:3]+ov.utils.red_color[5:],
                color=['celltype'],show=False)
# Out:
# <AxesSubplot: title={'center': 'celltype'}, xlabel='X_mde_lsi1', ylabel='X_mde_lsi2'>

# %%
atac.var['chromstart']=atac.var['chromStart']
atac.var['chromend']=atac.var['chromEnd']

# %%
adata=atac

# %%
# Filter out non-chromosomal regions
mask = adata.var["chrom"].str.startswith("chr")
adata = adata[:, mask].copy()

# %%
scvi.data.add_dna_sequence(
    adata,
    genome_name="hg38", 
    genome_dir="data",
    chr_var_key="chrom",
    start_var_key="chromstart",
    end_var_key="chromend",
)
adata

# %%
import numpy as np

# %%
bdata = adata.transpose()
bdata.layers["binary"] = (bdata.X.copy() > 0).astype(float)
scvi.external.SCBASSET.setup_anndata(bdata, layer="binary", dna_code_key="dna_code")
# Out:
# INFO     Generating sequential column names

# %%
bas = scvi.external.SCBASSET(bdata)
bas.train(precision=16)

# %%
fig, ax = plt.subplots()
bas.history_["train_loss_epoch"].plot(ax=ax)
bas.history_["validation_loss"].plot(ax=ax)

# %%
fig, ax = plt.subplots()
bas.history_["auroc_train"].plot(ax=ax)
bas.history_["auroc_validation"].plot(ax=ax)

# %%
latent = bas.get_latent_representation()
adata.obsm["X_scbasset"] = latent

print(latent.shape)

# %%
import seaborn as sns
print('seaborn(Ver): ',sns.__version__)

# %%
sns.scatterplot(
    x=bas.get_cell_bias(),
    y=np.log10(np.asarray(adata.X.sum(1))).ravel(),
    s=3,
)
plt.xlabel("Cell bias")
plt.ylabel("log10(UMI count)")

# %%
tfs = ["SP4",'EGR1','SMARCC2','ZNF263','SP3','CTCF','IRF1','ZBTB7B','ETS1','RREB1','IRF5','THAP1','RFX2','NFYA','SRF','MAZ','ZFX','HSF1','KLF15','PURA','ZNF274','RFX4','BCL6B','IRF4','NHLH1','SP2','PLAG1',
       'CTCFL','E2F1','ZNF148','ETV7','SOX2','SMARCC1','PTF1A','ETV6','PBX3','ZBTB33','ZBTB7A','POU5F1','JUNB','RUNX2','USF2','STAT3','ZNF143','RFX5','THRB','TBX2','BHLHE41','IRF3','MAFA','TFCP2','MAFF',
       'NFYB','KLF3','TFAP2D','PPARG','SPI1','SOX21','BCL11A','ZSCAN4','FOXC2','HEY2','TBX1','FOXO1','NR1I3','PRDM1','MEF2A','ESR1','TP73','BRCA1','SOX18','TFAP2C','RARG','NFIB','STAT2','BCL6','ARID3A','ELF2',
       'HIVEP2','ESRRA','ONECUT2','IRF8','AR','NFYC','CREB3','TEAD1','ESR2','TP53','HOXC6','ZNF410','ZIC4','TBX3','RUNX3','REST','FOSL2','ATF7','NFIX','NFIA','TGIF1','MEF2C','MLXIPL','RFX3','IRF2','CREB3L1',
       'TFDP1','MAFK','HESX1','KLF13','GATA3','NR2C2','GLIS2','ELF3','PAX8','PBX2','ZBTB4','ZBTB49','ZNF350','BARX1','NFAT5','TCF7L2','NR1D1','MTF1','RELA','MSX1','ZNF589','NR1H2','GATA2','ZNF713','FOXC1','TEF',
       'HNF4A','PAX2','SOX8','TFAP2A','NR2F6','NR2C1','ENO1','GATA5','ZSCAN16','NFIL3','HSF2','ZNF423','MYOG','HES1','TBX20','FOXD2','FOXO6','PKNOX1','ELF1','RXRG','MECOM','FOXP1','SOX7','OTX2','ZNF232','NR3C2',
       'PAX5','ZNF282','MEIS2','ETV5','ZBTB6','ARID5B','EPAS1','SOX17','NR3C1','NR2E3','BATF','E2F4','HINFP','PBX1','FOXO3','FOXA3','CEBPG','STAT4','ATF4','STAT6','NR6A1','MEIS1','HSF4','SCRT1','PPARD',
       'ONECUT1','BATF3','CDC5L','POU4F2','NFATC1','JUN','FOXM1','DDIT3','SCRT2','PRDM4','POU3F1','ZNF219','NEUROD1','ARNT2','CUX1','HNF1A','POU2F2','POU6F1','LHX2','HLF','REL','RELB','HIF1A','HES7','HES5','FOXJ3',
       'POU3F3','TBX19','SMAD1','INSM1','ATF6','ZNF524','ELK3','YY1','POU4F3','TEAD3','NKX3-1','ARX','STAT5B','POU4F1','ELF4','HIVEP1','RFX1','NFE2L2','HLTF','TBX15','LHX3','SOX4','ATF5','ZNF75A','TGIF2','PKNOX2',
       'E2F8','TCF7','NR2F1','HOXC8','ZKSCAN3','UNCX','IRF9','IRX2','E2F7','SP1','SPIB','TCF7L1','IRX5','TEAD4','STAT5A','MEF2D','MEF2B','RORA','DRGX','HAND1','EGR4','EGR2','KLF16','ZBTB7C','SOX14','FUBP1','BHLHE22',
       'ZNF384','MYBL1','TFAP4','NRF1','E2F6','ONECUT3','FOXQ1','ALX1','HOMEZ','XBP1','HMGA2','EOMES','SMAD2','RARB','YBX1','TLX1','KLF1','GLI3','ETS2','MXI1','GABPA','EBF1','USF1','BPTF','ATF3','GLI2','GLI1','ERG',
       'EGR3','TCF12','MBD2','HOXA7','CBFB','NFKB2','CREM','YY2','FOXH1','TCF3','CEBPZ','SPDEF','FOSL1','JUND','FOS','NFKB1','FLI1','GRHL1','GCM1','LBX2','SOX9','PAX6','NKX3-2','CEBPD','STAT1','CENPB','DBP','NRL',
       'CEBPA','GFI1B','HOXC11','HMX3','ETV2','PROX1','PLAGL1','KLF4','TFAP2B','KLF5','DNMT1','ZBED1','HOXB8','FOXP2','FOXF2','HMX2','CEBPB','ZNF740','DMRT3','VSX2','HMX1','TWIST1','GLIS3','HEY1','FOXF1','PHOX2B',
       'PHOX2A','CUX2','MNT','SMAD3','E2F5','E2F3','E2F2','BHLHE40','MYC','ELK4','ZFHX3','THRA','SREBF1','NEUROD2','MESP1','GSC2','GSC','ETV3','ERF','DMBX1','TFE3','NR4A3','TFEC','MYBL2','SREBF2','RXRB','FOSB','ZNF784',
       'ETV1','ESX1','BARHL2','BACH2','MAX','RAX','EN2','RUNX1','IRF7','FEV','TBR1','MSC','MLX','CLOCK','SIX5','NR2E1','GFI1','MIXL1','HOXB2','HMBOX1','GBX2','EVX2','EMX2','BHLHE23','ALX3','ZFHX2','EMX1','TLX2','OLIG2',
       'OLIG1','NEUROG2','PITX2','DLX3','POU6F2','HOXC10','HOXB3','ID4','ATF1','HOXB7','HOXA5','HOXB5','FOXK1','DMRTA2','DMRT1','NFATC4','FOXJ2','PAX7','PAX3','MNX1','TBP','POU3F2','DMRT2','MITF','ZIC2','ZIC1','MZF1',
       'TCF4','HIC1','HIC2','DLX1','TFEB','MYOD1','E4F1','ZEB1','TET1','SMAD4','MAFB','AHR','GMEB1','CREB1','ELK1','RBPJ','PITX3','PITX1','KDM2B','NR4A2','NR4A1','ESRRG','ESRRB','RHOXF1','ZNF333','NFATC3','JDP2','OVOL1',
       'HBP1','GATA4','FOXD3','POU2F1','NFATC2','POU5F1B','KLF6','FOXP3','FOXO4','ARNT','SNAI1','MYCN','BACH1','MAF','TBX5','ETV4','CRX','MGA','MEIS3','ZHX1','RXRA','OTX1','SHOX2','RAX2','LHX9','DLX6','DLX5','DLX4','NR2F2',
       'SOX13','ISL2','GMEB2','LHX6','VSX1','VAX2','FOXD1','FOXG1','NANOG','SOX5','HOXD4','LBX1','DLX2','LMX1A','CPEB1','MECP2','VDR','SNAI2','MYF6','CXXC1','RARA','MYB','PRRX1','PPARA','NKX2-5','NFE2L1','MAFG','SOX15',
       'LEF1','ISL1','PRRX2','MSX2','HMGA1'
       
      ]
for tf in tfs:
    adata.obs[f"bas_{tf}"] = bas.get_tf_activity(
        tf=tf,
        motif_dir="data/motifs",
    )

# %%
#如无法保存文件，请删掉adata.varm['dna']
adata.varm.pop('dna_sequence', None)
adata.varm.pop('dna_code', None)

# %%
adata.write_h5ad('/mnt/home/yihanzhao/RB/data/atac_tf.h5ad',compression='gzip')

# %% [markdown]
# ## 导出TF活性

# %%
adata=sc.read_h5ad('/mnt/home/yihanzhao/RB/data/atac_tf.h5ad')

# %%
#P-p
adata[adata.obs[adata.obs['celltype']=='P-p']]

# %%
adata.obs.to_csv('P-p.csv')

# %%
#Cone
adata[adata.obs[adata.obs['celltype']=='Cone']]

# %%
adata.obs.to_csv('cone.csv')

# %%
#Cone-tumor
adata[adata.obs[adata.obs['celltype']=='Cone-tumor']]

# %%
adata.obs.to_csv('cone-tumor.csv')

# %% [markdown]
# ## chromvar

# %%
motif=sc.read_h5ad('/mnt/home/yihanzhao/RB/data_new/atac_motif_raw.h5ad')
motif
# Out:
# AnnData object with n_obs × n_vars = 85418 × 746

# %%
atac=sc.read_h5ad('/mnt/home/yihanzhao/RB/data_new/atac_anno_new.h5ad')
atac
# Out:
# AnnData object with n_obs × n_vars = 85418 × 150000
#     obs: 'sample', 'week', 'tissue', 'balancing_weight', 'domain', 'transf_celltype', 'celltype'
#     var: 'chrom', 'chromStart', 'chromEnd', 'highly_variable'
#     uns: 'AnnDataSet', '__scglue__', 'celltype_colors', 'neighbors', 'reference_sequences', 'sample_colors', 'transf_celltype_colors', 'umap'
#     obsm: 'X_glue', 'X_lsi', 'X_mde_lsi', 'X_mde_scglue', 'X_umap'
#     varm: 'X_glue'
#     obsp: 'connectivities', 'distances'

# %%
motif.obs['tissue']=atac.obs['tissue']
motif.obs['celltype']=atac.obs['celltype']

# %% [markdown]
# ### motif计算

# %%
retina=sc.read_h5ad('/mnt/home/yihanzhao/RB/data_new/atac_retina_pair_zhushi.h5ad')

# %%
import pychromvar as pc
pc.add_peak_seq(retina, genome_file="/mnt/home/zehuazeng/data/fastq/hg38/hg38.fa", delimiter=":|-")
pc.add_gc_bias(retina)
pc.get_bg_peaks(retina)
# Out:
# 100%|██████████████████████████████████████████| 150000/150000 [00:11<00:00, 12910.11it/s]
# 100%|██████████████████████████████████████████| 150000/150000 [00:06<00:00, 23788.56it/s]

# %%
from pyjaspar import jaspardb
# get motifs
jdb_obj = jaspardb(release='JASPAR2020')
motifs = jdb_obj.fetch_motifs(
    collection = 'CORE',
    tax_group = ['vertebrates'])

# %%
pc.match_motif(retina, motifs=motifs)
# Out:
# 100%|████████████████████████████████████████████| 150000/150000 [07:15<00:00, 344.66it/s]

# %%
retina
# Out:
# AnnData object with n_obs × n_vars = 12709 × 150000
#     obs: 'sample', 'tissue', 'domain', 'week', 'balancing_weight', 'celltype'
#     var: 'chrom', 'chromStart', 'chromEnd', 'highly_variable', 'gc_bias'
#     uns: 'celltype_colors', 'peak_seq', 'motif_name'
#     obsm: 'X_glue', 'X_lsi', 'X_mde_lsi', 'X_mde_scglue', 'X_umap'
#     varm: 'bg_peaks', 'motif_match'

# %%
dev = pc.compute_deviations(retina,n_jobs=1)
dev
# Out:
# 2024-05-17 14:40:38 INFO     computing expectation reads per cell and peak...
# 2024-05-17 14:40:46 INFO     computing observed motif deviations...
# 2024-05-17 14:41:13 INFO     computing background deviations...
# AnnData object with n_obs × n_vars = 12709 × 746

# %%
dev.obs['tissue']=retina.obs['tissue']
dev.obs['celltype']=retina.obs['celltype']

# %%
dev.write('/mnt/home/yihanzhao/RB/data_new/retina_motif.h5ad',compression='gzip')

# %%
rb=sc.read_h5ad('/mnt/home/yihanzhao/RB/data_new/atac_rb_pair_zhushi.h5ad')

# %%
import numpy as np

# %%
import pychromvar as pc
pc.add_peak_seq(rb, genome_file="/mnt/home/zehuazeng/data/fastq/hg38/hg38.fa", delimiter=":|-")
pc.add_gc_bias(rb)
# Out:
# 100%|██████████████████████████████████████████| 150000/150000 [00:04<00:00, 34744.40it/s]
# 100%|██████████████████████████████████████████| 150000/150000 [00:06<00:00, 23859.72it/s]

# %%
retina.X.max()
# Out:
# 47.0

# %%
rb.X.max()
# Out:
# 30.0

# %%
rb.uns.drop(columns=["highly_variable"], inplace=True)

# %%
rb = rb[rb.obs!=['sample']]
#adata = adata[adata.obs['celltype']!='BC']
#adata = adata[adata.obs['celltype']!='FB']
#adata = adata[adata.obs['celltype']!='HC']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_180787/3582278406.py in <cell line: 1>()
# ----> 1 rb = rb[rb.obs!=['sample']]
#       2 #adata = adata[adata.obs['celltype']!='BC']
#       3 #adata = adata[adata.obs['celltype']!='FB']
#       4 #adata = adata[adata.obs['celltype']!='HC']
#
# /mnt/data/env/pyomic/lib/python3.8/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      70         other = item_from_zerodim(other)
#      71
# ---> 72         return method(self, other)
#      73
#      74     return new_method
#
# /mnt/data/env/pyomic/lib/python3.8/site-packages/pandas/core/arraylike.py in __ne__(self, other)
#      44     @unpack_zerodim_and_defer("__ne__")
#      45     def __ne__(self, other):
# ---> 46         return self._cmp_method(other, operator.ne)
#      47
#      48     @unpack_zerodim_and_defer("__lt__")
#
# /mnt/data/env/pyomic/lib/python3.8/site-packages/pandas/core/frame.py in _cmp_method(self, other, op)
#    7577         axis = 1  # only relevant for Series other case
#    7578
# -> 7579         self, other = ops.align_method_FRAME(self, other, axis, flex=False, level=None)
#    7580
#    7581         # See GH#4537 for discussion of scalar op behavior
#
# /mnt/data/env/pyomic/lib/python3.8/site-packages/pandas/core/ops/__init__.py in align_method_FRAME(left, right, axis, flex, level)
#     280             )
#     281         # GH17901
# --> 282         right = to_series(right)
#     283
#     284     if flex is not None and isinstance(right, ABCDataFrame):
#
# /mnt/data/env/pyomic/lib/python3.8/site-packages/pandas/core/ops/__init__.py in to_series(right)
#     237         else:
#     238             if len(left.columns) != len(right):
# --> 239                 raise ValueError(
#     240                     msg.format(req_len=len(left.columns), given_len=len(right))
#     241                 )
#
# ValueError: Unable to coerce to Series, length must be 6: given 1

# %%
pc.get_bg_peaks(rb)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_180787/48745735.py in <cell line: 1>()
# ----> 1 pc.get_bg_peaks(rb)
#
# /mnt/data/env/pyomic/lib/python3.8/site-packages/pychromvar/preprocessing.py in get_bg_peaks(data, niterations, n_jobs)
#      48     mat = np.array([reads_per_peak, adata.var['gc_bias'].values])
#      49     chol_cov_mat = np.linalg.cholesky(np.cov(mat))
# ---> 50     trans_norm_mat = sp.linalg.solve_triangular(
#      51         a=chol_cov_mat, b=mat, lower=True).transpose()
#      52
#
# /mnt/data/env/pyomic/lib/python3.8/site-packages/scipy/linalg/_basic.py in solve_triangular(a, b, trans, lower, unit_diagonal, overwrite_b, check_finite)
#     331     """
#     332
# --> 333     a1 = _asarray_validated(a, check_finite=check_finite)
#     334     b1 = _asarray_validated(b, check_finite=check_finite)
#     335     if len(a1.shape) != 2 or a1.shape[0] != a1.shape[1]:
#
# /mnt/data/env/pyomic/lib/python3.8/site-packages/scipy/_lib/_util.py in _asarray_validated(a, check_finite, sparse_ok, objects_ok, mask_ok, as_inexact)
#     285             raise ValueError('masked arrays are not supported')
#     286     toarray = np.asarray_chkfinite if check_finite else np.asarray
# --> 287     a = toarray(a)
#     288     if not objects_ok:
#     289         if a.dtype is np.dtype('O'):
#
# /mnt/data/env/pyomic/lib/python3.8/site-packages/numpy/lib/function_base.py in asarray_chkfinite(a, dtype, order)
#     625     a = asarray(a, dtype=dtype, order=order)
#     626     if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
# --> 627         raise ValueError(
#     628             "array must not contain infs or NaNs")
#     629     return a
#
# ValueError: array must not contain infs or NaNs

# %% [markdown]
# ## 活性

# %%
motif=sc.read_h5ad('/mnt/home/yihanzhao/RB/data_new/motif.h5ad')
motif
# Out:
# AnnData object with n_obs × n_vars = 13438 × 746
#     obs: 'tissue', 'celltype'

# %%
import anndata

# %%
retina_rna=sc.read_h5ad('/mnt/home/yihanzhao/RB/data_new/rna_retina_pair_zhushi.h5ad')
rb_rna=sc.read_h5ad('/mnt/home/yihanzhao/RB/data_new/rna_rb_pair_zhushi.h5ad')
rna= anndata.concat([retina_rna,rb_rna],merge='same')
rna
# Out:
# AnnData object with n_obs × n_vars = 13438 × 16288
#     obs: 'tissue', 'domain', 'sample', 'nUMIs', 'mito_perc', 'detected_genes', 'cell_complexity', 'doublet_score', 'predicted_doublet', 'passing_mt', 'passing_nUMIs', 'passing_ngenes', 'n_genes', 'balancing_weight', 'celltype'
#     var: 'feature_types', 'mt', 'robust', 'chrom', 'chromStart', 'chromEnd', 'name', 'score', 'strand', 'thickStart', 'thickEnd', 'itemRgb', 'blockCount', 'blockSizes', 'blockStarts', 'gene_id', 'gene_type', 'dell'
#     obsm: 'X_glue', 'X_mde_pca', 'X_mde_scVI', 'X_scVI', 'scaled|original|X_pca'
#     layers: 'counts', 'lognorm', 'scaled'

# %%
retina_atac=sc.read_h5ad('/mnt/home/yihanzhao/RB/data_new/atac_retina_pair_zhushi.h5ad')
rb_atac=sc.read_h5ad('/mnt/home/yihanzhao/RB/data_new/atac_rb_pair_zhushi.h5ad')
atac= anndata.concat([retina_atac,rb_atac],merge='same')
atac
# Out:
# AnnData object with n_obs × n_vars = 13438 × 150000
#     obs: 'sample', 'tissue', 'domain', 'week', 'balancing_weight', 'celltype'
#     var: 'chrom', 'chromStart', 'chromEnd'
#     obsm: 'X_glue', 'X_lsi', 'X_mde_lsi', 'X_umap'

# %% [markdown]
# ### rna重注释

# %%
ov.utils.embedding(rb_rna,
                basis='X_mde_scVI',frameon='small',palette=ov.utils.orange_color[5:6]+ov.utils.orange_color[0:1]+ov.utils.orange_color[7:8]+ov.utils.orange_color[9:10]+ov.utils.orange_color[6:7]+ov.utils.red_color[:1]+ov.utils.red_color[1:2]+ov.utils.red_color[3:4]+ov.utils.red_color[2:3]+ov.utils.red_color[5:],
                color=['celltype'],show=False)
# Out:
# <AxesSubplot: title={'center': 'celltype'}, xlabel='X_mde_scVI1', ylabel='X_mde_scVI2'>

# %%
from scvi.model.utils import mde
rb_rna.obsm["X_mde_scVI"] = mde(rb_rna.obsm["X_scVI"])

# %%
sc.pp.neighbors(rb_rna, use_rep="X_scVI", metric="cosine",n_neighbors=10, random_state = 112)
sc.tl.leiden(rb_rna)
sc.tl.paga(rb_rna)
sc.pl.paga(rb_rna, plot=False)  # remove `plot=False` if you want to see the coarse-grained graph
sc.tl.umap(rb_rna,init_pos='paga')
# Out:
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:04)
# running Leiden clustering
#     finished: found 13 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:00)
# running PAGA
#     finished: added
#     'paga/connectivities', connectivities adjacency (adata.uns)
#     'paga/connectivities_tree', connectivities subtree (adata.uns) (0:00:00)
# --> added 'pos', the PAGA positions (adata.uns['paga'])
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:01)

# %%
ov.utils.embedding(rb_rna,
                basis='X_mde_scVI',frameon='small',palette=ov.utils.red_color+ov.utils.green_color+ov.utils.orange_color,
                color=['leiden'],show=False)
# Out:
# <AxesSubplot: title={'center': 'leiden'}, xlabel='X_mde_scVI1', ylabel='X_mde_scVI2'>

# %%
small_marker_dict={
    'Rod': ['NRL','NR2E3','GNAT1','GRM8','PDC','CA2'],
    'Rod pre': ['CRX','RCVRN'],
    'Tumor cells':['HELLS','MCM3','PCNA'],
    'CPC':['ARR3','GUCA1A','RXRG'],
 'P-p':['APOLD1','ASMP','CENPF','GTSE1'],
'Middle':['EGFLAM','CAMK1D','ANKRD33B'],
    'TCR':['USPL1','ZFAS1'],
    'Cone': ['PDE6H','GUCA1C','ARR3','GNAT2','STXBP5L','MYO3A','GRM8'],
    'RSC':['TUBA1A','RBP1']
}
# check if the markers are in the data
smarker_genes_in_data = dict()
for ct, markers in small_marker_dict.items():
    markers_found = list()
    for marker in markers:
        if marker in rb_rna.raw.var_names:
            markers_found.append(marker)
    smarker_genes_in_data[ct] = markers_found
#del [] # remove the last marker
del_markers = list()
for ct, markers in smarker_genes_in_data.items():
    if markers==[]:
        del_markers.append(ct)
for ct in del_markers:
    del smarker_genes_in_data[ct]

# %%
sc.tl.dendrogram(rb_rna,groupby='leiden',use_rep='X_scVI')
sc.pl.dotplot(
    rb_rna,
    groupby="leiden",
    var_names=smarker_genes_in_data,
    dendrogram=True,
    standard_scale="var",  # standard scale: normalize each gene to range from 0 to 1
)
# Out:
# Storing dendrogram info using `.uns['dendrogram_leiden']`
# WARNING: Groups are not reordered because the `groupby` categories and the `var_group_labels` are different.
# categories: 0, 1, 2, etc.
# var_group_labels: Rod, Rod pre, Tumor cells, etc.

# %%
cluster2annotation = {
    '0': 'RSC',#1
    '1': 'Rod pre',#1
    '2': 'P-p',#1
    '3': 'CPC',#1
    '4': 'P-p',#1
    '5': 'RSC',#1
    '6': 'RSC',#1
    '7': 'Middle',#1
    '8': 'Rod',#1
    '9': 'Cone-tumor',#1
    '10': 'Cone',#1
    '11': 'TCR',#1
    '12':'RSC'
}
rb_rna.obs['celltype'] = rb_rna.obs['leiden'].map(cluster2annotation).astype('category')

# %%
rb_rna.write('/mnt/home/yihanzhao/RB/data_new/rb_rna.h5ad',compression='gzip')

# %%
rb_rna=sc.read_h5ad('/mnt/home/yihanzhao/RB/data_new/rb_rna.h5ad')

# %% [markdown]
# ### atac迁移

# %%
ov.utils.embedding(rb_rna,
                basis='X_mde_scVI',frameon='small',palette=ov.utils.orange_color[5:6]+ov.utils.orange_color[0:1]+ov.utils.orange_color[7:8]+ov.utils.orange_color[9:10]+ov.utils.orange_color[6:7]+ov.utils.red_color[1:2]+ov.utils.red_color[3:4]+ov.utils.red_color[2:3]+ov.utils.red_color[5:],
                color=['celltype'],show=False)
# Out:
# <AxesSubplot: title={'center': 'celltype'}, xlabel='X_mde_scVI1', ylabel='X_mde_scVI2'>

# %%
rb_atac.obs['celltype']=rb_rna.obs['celltype']

# %%
pip install pymde

# %%
from scvi.model.utils import mde
rb_atac.obsm["X_mde_lsi"] = mde(rb_atac.obsm["X_lsi"])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/miniconda3/envs/zyh/lib/python3.10/site-packages/scvi/model/utils/_mde.py:68, in mde(data, accelerator, device, seed, **kwargs)
#      67 try:
# ---> 68     import pymde
#      69 except ImportError as err:
#
# ModuleNotFoundError: No module named 'pymde'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[14], line 2
#       1 from scvi.model.utils import mde
# ----> 2 rb_atac.obsm["X_mde_lsi"] = mde(rb_atac.obsm["X_lsi"])
#
# File ~/miniconda3/envs/zyh/lib/python3.10/site-packages/scvi/model/utils/_mde.py:70, in mde(data, accelerator, device, seed, **kwargs)
#      68     import pymde
#      69 except ImportError as err:
# ---> 70     raise ImportError("Please install pymde package via `pip install pymde`") from err
#      72 if seed is None and settings.seed is not None:
#      73     seed = settings.seed
#
# ImportError: Please install pymde package via `pip install pymde`

# %%
ov.utils.embedding(rb_atac,
                basis='X_mde_lsi',frameon='small',palette=ov.utils.orange_color[5:6]+ov.utils.orange_color[0:1]+ov.utils.orange_color[7:8]+ov.utils.orange_color[9:10]+ov.utils.orange_color[6:7]+ov.utils.red_color[1:2]+ov.utils.red_color[3:4]+ov.utils.red_color[2:3]+ov.utils.red_color[5:],
                color=['celltype'],show=False)
# Out:
# <AxesSubplot: title={'center': 'celltype'}, xlabel='X_mde_lsi1', ylabel='X_mde_lsi2'>

# %%
motif_rb=motif[motif.obs['tissue']=='rb']

# %%
motif_rb.obs['celltype']=rb_atac.obs['celltype']

# %%
sc.tl.rank_genes_groups(motif_rb, 'celltype', method='wilcoxon', use_raw=False)
# Out:
# ranking genes
#     finished: added to `.uns['rank_genes_groups']`
#     'names', sorted np.recarray to be indexed by group ids
#     'scores', sorted np.recarray to be indexed by group ids
#     'logfoldchanges', sorted np.recarray to be indexed by group ids
#     'pvals', sorted np.recarray to be indexed by group ids
#     'pvals_adj', sorted np.recarray to be indexed by group ids (0:00:00)

# %%
motif_rb.raw = motif_rb

# %%
motif_rb.obsm=rb_atac.obsm

# %%
import pandas as pd

# %%
pd.DataFrame(motif_rb.uns['rank_genes_groups']['names']).head(50)
# Out:
#                        CPC                    Cone              Cone-tumor  \
# 0            MA0139.1.CTCF          MA1513.1.KLF15          MA0131.2.HINFP
# 1           MA0131.2.HINFP           MA0506.1.NRF1           MA0506.1.NRF1
# 2           MA1122.1.TFDP1          MA0131.2.HINFP          MA1122.1.TFDP1
# 3           MA0740.1.KLF14          MA0846.1.FOXC2         MA1650.1.ZBTB14
# 4            MA1516.1.KLF3         MA1650.1.ZBTB14          MA0632.2.TCFL5
# 5            MA0506.1.NRF1          MA0851.1.Foxj3          MA1513.1.KLF15
# 6   MA0812.1.TFAP2B(var.2)  MA0815.1.TFAP2C(var.3)           MA0162.4.EGR1
# 7          MA1650.1.ZBTB14  MA0813.1.TFAP2B(var.3)          MA0647.1.GRHL1
# 8            MA0738.1.HIC2         MA0629.1.Rhox11           MA0471.2.E2F6
# 9           MA1581.1.ZBTB6          MA0052.4.MEF2A         MA1569.1.TFAP2E
# 10          MA0862.1.GMEB2          MA1471.1.BARX2           MA1419.1.IRF4
# 11          MA0773.1.MEF2D          MA0032.2.FOXC1          MA1102.2.CTCFL
# 12    MA0259.1.ARNT::HIF1A          MA1102.2.CTCFL           MA0733.1.EGR4
# 13          MA1513.1.KLF15           MA1516.1.KLF3           MA1584.1.ZIC5
# 14           MA0830.2.TCF4          MA0740.1.KLF14  MA0815.1.TFAP2C(var.3)
# 15          MA0851.1.Foxj3         MA0787.1.POU3F2         MA0527.1.ZBTB33
# 16          MA1106.1.HIF1A           MA0162.4.EGR1           MA0472.2.EGR2
# 17         MA0629.1.Rhox11         MA0811.1.TFAP2B            MA1564.1.SP9
# 18         MA1530.1.NKX6-3           MA1515.1.KLF2          MA0619.1.LIN54
# 19           MA1542.1.OSR1          MA0637.1.CENPB  MA0813.1.TFAP2B(var.3)
# 20           MA1584.1.ZIC5           MA0470.2.E2F4           MA0139.1.CTCF
# 21  MA0810.1.TFAP2A(var.2)         MA1653.1.ZNF148          MA0740.1.KLF14
# 22          MA0637.1.CENPB           MA1517.1.KLF6  MA0872.1.TFAP2A(var.3)
# 23          MA0643.1.Esrrg         MA0789.1.POU3F4  MA0810.1.TFAP2A(var.2)
# 24          MA0032.2.FOXC1           MA1418.1.IRF3           MA0697.1.ZIC3
# 25  MA0872.1.TFAP2A(var.3)  MA0872.1.TFAP2A(var.3)          MA0031.1.FOXD1
# 26         MA0811.1.TFAP2B           MA1584.1.ZIC5          MA0157.2.FOXO3
# 27         MA1569.1.TFAP2E        MA0679.2.ONECUT1            MA0746.2.SP3
# 28          MA0046.2.HNF1A          MA0632.2.TCFL5           MA1099.2.HES1
# 29           MA0696.1.ZIC1          MA1607.1.Foxl2           MA0732.1.EGR3
# 30         MA1649.1.ZBTB12         MA0785.1.POU2F1         MA1125.1.ZNF384
# 31         MA0789.1.POU3F4          MA0845.1.FOXB1          MA1471.1.BARX2
# 32         MA0750.2.ZBTB7A        MA0792.1.POU5F1B           MA0696.1.ZIC1
# 33          MA0660.1.MEF2B  MA0810.1.TFAP2A(var.2)          MA0145.3.TFCP2
# 34         MA1657.1.ZNF652          MA0497.1.MEF2C           MA0652.1.IRF8
# 35           MA0652.1.IRF8         MA0791.1.POU4F3         MA1657.1.ZNF652
# 36          MA0614.1.Foxj2            MA0084.1.SRY         MA0694.1.ZBTB7B
# 37          MA0613.1.FOXG1         MA0681.2.PHOX2B         MA0750.2.ZBTB7A
# 38           MA1515.1.KLF2            MA1564.1.SP9           MA0772.1.IRF7
# 39          MA0847.2.FOXD2          MA0773.1.MEF2D         MA0683.1.POU4F2
# 40  MA0815.1.TFAP2C(var.3)          MA0847.2.FOXD2          MA1463.1.ARGFX
# 41          MA1540.1.NR5A1         MA0627.2.POU2F3          MA0032.2.FOXC1
# 42            MA0146.2.Zfx         MA0901.2.HOXB13         MA0901.2.HOXB13
# 43          MA0036.3.GATA2        MA0757.1.ONECUT3          MA1607.1.Foxl2
# 44          MA1471.1.BARX2          MA0619.1.LIN54           MA1516.1.KLF3
# 45           MA0465.2.CDX2          MA1545.1.OVOL2           MA0751.1.ZIC4
# 46        MA0792.1.POU5F1B         MA0507.1.POU2F2          MA0497.1.MEF2C
# 47          MA1561.1.SOX12          MA0041.1.Foxd3          MA0052.4.MEF2A
# 48            MA0843.1.TEF         MA0635.1.BARHL2           MA0465.2.CDX2
# 49          MA0025.2.NFIL3            MA0746.2.SP3         MA0524.2.TFAP2C
#
#                     Middle                      P-p                      RSC  \
# 0          MA1650.1.ZBTB14             MA0648.1.GSC     MA1142.1.FOSL1::JUND
# 1           MA0740.1.KLF14            MA0891.1.GSC2            MA0490.2.JUNB
# 2           MA0497.1.MEF2C           MA0883.1.Dmbx1            MA0491.2.JUND
# 3            MA1516.1.KLF3           MA0714.1.PITX3      MA1128.1.FOSL1::JUN
# 4            MA1515.1.KLF2            MA0712.2.OTX2      MA1130.1.FOSL2::JUN
# 5           MA0052.4.MEF2A           MA0682.2.PITX1           MA0477.2.FOSL1
# 6            MA0822.1.HES7            MA1480.1.DPRX        MA0099.3.FOS::JUN
# 7           MA1513.1.KLF15           MA1547.1.PITX2           MA0478.1.FOSL2
# 8            MA0506.1.NRF1           MA0461.2.Atoh1       MA1134.1.FOS::JUNB
# 9           MA0773.1.MEF2D             MA0467.1.Crx     MA1144.1.FOSL2::JUND
# 10          MA0660.1.MEF2B         MA0668.1.NEUROD2       MA1141.1.FOS::JUND
# 11          MA0041.1.Foxd3            MA0056.2.MZF1     MA1138.1.FOSL2::JUNB
# 12            MA0146.2.Zfx         MA0669.1.NEUROG2            MA0655.1.JDP2
# 13          MA0846.1.FOXC2           MA1618.1.Ptf1a      MA1135.1.FOSB::JUNB
# 14          MA0131.2.HINFP            MA1113.2.PBX2    MA1622.1.Smad2::Smad3
# 15         MA1125.1.ZNF384          MA0719.1.RHOXF1     MA1137.1.FOSL1::JUNB
# 16           MA0472.2.EGR2    MA1568.1.TCF21(var.2)       MA1132.1.JUN::JUNB
# 17            MA1564.1.SP9             MA0083.3.SRF           MA1101.2.BACH2
# 18  MA0829.2.SREBF1(var.2)      MA0091.1.TAL1::TCF3             MA0476.1.FOS
# 19           MA0821.1.HES5    MA1570.1.TFAP4(var.2)      MA0489.1.JUN(var.2)
# 20            MA0746.2.SP3         MA0623.2.NEUROG1            MA0841.1.NFE2
# 21           MA1099.2.HES1          MA0633.1.Twist2       MA0462.2.BATF::JUN
# 22           MA1517.1.KLF6           MA0826.1.OLIG1            MA1634.1.BATF
# 23          MA0632.2.TCFL5            MA1117.1.RELB           MA0835.2.BATF3
# 24          MA0838.1.CEBPG     MA0860.1.Rarg(var.2)            MA1637.1.EBF3
# 25           MA0805.1.TBX1           MA1468.1.ATOH7            MA1604.1.Ebf2
# 26          MA0862.1.GMEB2         MA1109.1.NEUROD1           MA1633.1.BACH1
# 27          MA0637.1.CENPB  MA1642.1.NEUROG2(var.2)     MA0591.1.Bach1::Mafk
# 28          MA0032.2.FOXC1           MA1638.1.HAND2  MA1642.1.NEUROG2(var.2)
# 29           MA0112.3.ESR1          MA1123.2.TWIST1            MA0154.4.EBF1
# 30           MA0050.2.IRF1    MA1640.1.MEIS2(var.2)         MA1109.1.NEUROD1
# 31           MA0859.1.Rarg         MA0818.1.BHLHE22  MA1635.1.BHLHE22(var.2)
# 32            MA0685.1.SP4           MA0678.1.OLIG2           MA1638.1.HAND2
# 33          MA0845.1.FOXB1           MA0498.2.MEIS1      MA0091.1.TAL1::TCF3
# 34          MA1122.1.TFDP1           MA0035.4.GATA1           MA1618.1.Ptf1a
# 35          MA1106.1.HIF1A    MA1467.1.ATOH1(var.2)          MA0089.2.NFE2L1
# 36            MA0801.1.MGA            MA1509.1.IRF6  MA1472.1.BHLHA15(var.2)
# 37   MA0728.1.Nr2f6(var.2)            MA0502.2.NFYB           MA1468.1.ATOH7
# 38           MA0653.1.IRF9           MA1505.1.HOXC8    MA1467.1.ATOH1(var.2)
# 39           MA0162.4.EGR1           MA0827.1.OLIG3            MA0258.2.ESR2
# 40           MA1567.1.TBX6            MA0754.1.CUX1          MA1485.1.FERD3L
# 41    MA0259.1.ARNT::HIF1A           MA1524.1.MSGN1           MA0521.1.Tcf12
# 42          MA1102.2.CTCFL            MA1481.1.DRGX           MA0832.1.Tcf21
# 43            MA0079.4.SP1            MA0132.2.PDX1            MA1641.1.MYF5
# 44          MA1471.1.BARX2    MA1639.1.MEIS1(var.2)            MA1629.1.Zic2
# 45           MA0028.2.ELK1            MA0755.1.CUX2    MA1619.1.Ptf1a(var.2)
# 46           MA0652.1.IRF8            MA0884.1.DUXA          MA1123.2.TWIST1
# 47           MA0616.2.HES2            MA0154.4.EBF1         MA0669.1.NEUROG2
# 48          MA0803.1.TBX15            MA1604.1.Ebf2    MA1568.1.TCF21(var.2)
# 49          MA1581.1.ZBTB6            MA1637.1.EBF3          MA1597.1.ZNF528
#
#                       Rod                  Rod pre                     TCR
# 0   MA1620.1.Ptf1a(var.3)             MA0095.2.YY1         MA1653.1.ZNF148
# 1          MA1621.1.Rbpjl             MA0748.2.YY2          MA1513.1.KLF15
# 2         MA1649.1.ZBTB12          MA1589.1.ZNF140          MA0025.2.NFIL3
# 3          MA1651.1.ZFP42            MA0496.3.MAFK          MA1122.1.TFDP1
# 4           MA1643.1.NFIB    MA0728.1.Nr2f6(var.2)         MA0785.1.POU2F1
# 5          MA1565.1.TBX18            MA0884.1.DUXA           MA0865.1.E2F8
# 6    MA0065.2.Pparg::Rxra   MA0828.1.SREBF2(var.2)           MA0885.1.Dlx2
# 7           MA0139.1.CTCF   MA0829.2.SREBF1(var.2)           MA0696.1.ZIC1
# 8        MA1523.1.MSANTD3            MA0093.3.USF1          MA0442.2.SOX10
# 9   MA0517.1.STAT1::STAT2            MA0526.3.USF2           MA0618.1.LBX1
# 10          MA0738.1.HIC2         MA1571.1.TGIF2LX         MA0788.1.POU3F3
# 11          MA0136.2.ELF5          MA0664.1.MLXIPL          MA0851.1.Foxj3
# 12         MA0745.2.SNAI2            MA0004.1.Arnt          MA0075.3.PRRX2
# 13           MA0665.1.MSC            MA0692.1.TFEB           MA0162.4.EGR1
# 14         MA0832.1.Tcf21            MA1484.1.ETS2           MA0732.1.EGR3
# 15        MA1580.1.ZBTB32             MA0663.1.MLX          MA0131.2.HINFP
# 16         MA1559.1.SNAI3            MA0759.1.ELK3          MA1102.2.CTCFL
# 17   MA1527.1.NFIC(var.2)            MA1604.1.Ebf2  MA0872.1.TFAP2A(var.3)
# 18           MA0801.1.MGA         MA0636.1.BHLHE41           MA0722.1.VAX1
# 19          MA0475.2.FLI1            MA0831.2.TFE3         MA1650.1.ZBTB14
# 20          MA0799.1.RFX4           MA0017.2.NR2F1         MA0790.1.POU4F1
# 21         MA0521.1.Tcf12            MA0154.4.EBF1         MA0787.1.POU3F2
# 22         MA0820.1.FIGLA           MA1464.1.ARNT2           MA0707.1.MNX1
# 23         MA0499.2.MYOD1         MA1109.1.NEUROD1         MA0811.1.TFAP2B
# 24         MA0157.2.FOXO3           MA1531.1.NR1D1          MA1463.1.ARGFX
# 25         MA0031.1.FOXD1          MA0089.2.NFE2L1         MA0524.2.TFAP2C
# 26          MA0463.2.BCL6            MA0028.2.ELK1         MA0152.1.NFATC2
# 27         MA0073.1.RREB1         MA1572.1.TGIF2LY          MA0621.1.mix-a
# 28         MA0144.2.STAT3  MA1642.1.NEUROG2(var.2)           MA0506.1.NRF1
# 29          MA1566.1.TBX3            MA0620.3.MITF         MA0601.1.Arid3b
# 30          MA0620.3.MITF           MA1532.1.NR1D2  MA0815.1.TFAP2C(var.3)
# 31         MA0442.2.SOX10          MA0681.2.PHOX2B           MA0135.1.Lhx3
# 32          MA1108.2.MXI1           MA1623.1.Stat2         MA0786.1.POU3F1
# 33         MA1112.2.NR4A1           MA1633.1.BACH1          MA1500.1.HOXB6
# 34          MA0640.2.ELF3          MA0719.1.RHOXF1  MA0810.1.TFAP2A(var.2)
# 35         MA0743.2.SCRT1            MA0522.3.TCF3          MA0703.2.LMX1B
# 36          MA0798.2.RFX3    MA1648.1.TCF12(var.2)           MA0723.1.VAX2
# 37          MA0763.1.ETV3          MA0782.2.PKNOX1           MA0463.2.BCL6
# 38          MA0028.2.ELK1    MA0019.1.Ddit3::Cebpa          MA0153.2.HNF1B
# 39        MA0750.2.ZBTB7A            MA1108.2.MXI1           MA0652.1.IRF8
# 40          MA1641.1.MYF5             MA0156.2.FEV           MA0653.1.IRF9
# 41          MA0509.2.RFX1           MA0778.1.NFKB2          MA0520.1.Stat6
# 42    MA0119.1.NFIC::TLX1           MA0777.1.MYBL2           MA0471.2.E2F6
# 43          MA0111.1.Spz1            MA0655.1.JDP2          MA1607.1.Foxl2
# 44          MA1584.1.ZIC5    MA1636.1.CEBPG(var.2)         MA0906.1.HOXC12
# 45  MA1619.1.Ptf1a(var.2)    MA1620.1.Ptf1a(var.3)          MA1603.1.Dmrt1
# 46         MA1607.1.Foxl2           MA0622.1.Mlxip           MA0700.2.LHX2
# 47   MA1552.1.RARB(var.3)            MA1114.1.PBX3           MA0697.1.ZIC3
# 48          MA0696.1.ZIC1          MA0596.1.SREBF2          MA0613.1.FOXG1
# 49          MA0038.2.GFI1            MA0864.2.E2F2          MA0614.1.Foxj2

# %%
motif_rb2 = motif_rb[motif_rb.obs['celltype']!='CPC']
motif_rb2 = motif_rb2[motif_rb2.obs['celltype']!='Middle']
motif_rb2 = motif_rb2[motif_rb2.obs['celltype']!='RSC']
motif_rb2 = motif_rb2[motif_rb2.obs['celltype']!='Rod']
motif_rb2 = motif_rb2[motif_rb2.obs['celltype']!='Rod pre']
motif_rb2 = motif_rb2[motif_rb2.obs['celltype']!='TCR']

# %%
motif_rb2.raw = motif_rb2

# %%
sc.tl.rank_genes_groups(motif_rb2, 'celltype', method='wilcoxon', use_raw=True)
# Out:
# ranking genes
#     finished: added to `.uns['rank_genes_groups']`
#     'names', sorted np.recarray to be indexed by group ids
#     'scores', sorted np.recarray to be indexed by group ids
#     'logfoldchanges', sorted np.recarray to be indexed by group ids
#     'pvals', sorted np.recarray to be indexed by group ids
#     'pvals_adj', sorted np.recarray to be indexed by group ids (0:00:00)

# %%
motif_rb.obsm=rb_atac.obsm

# %%
ov.utils.embedding(rb_atac,
                basis='X_mde_lsi',frameon='small',palette=ov.utils.orange_color[5:6]+ov.utils.orange_color[0:1]+ov.utils.orange_color[7:8]+ov.utils.orange_color[9:10]+ov.utils.orange_color[6:7]+ov.utils.red_color[1:2]+ov.utils.red_color[3:4]+ov.utils.red_color[2:3]+ov.utils.red_color[5:],
                color=['celltype'],show=False)
# Out:
# <AxesSubplot: title={'center': 'celltype'}, xlabel='X_mde_lsi1', ylabel='X_mde_lsi2'>

# %%
ov.utils.embedding(rb_rna,
                basis='X_mde_scVI',frameon='small',palette=ov.utils.orange_color[5:6]+ov.utils.orange_color[0:1]+ov.utils.orange_color[7:8]+ov.utils.orange_color[9:10]+ov.utils.orange_color[6:7]+ov.utils.red_color[1:2]+ov.utils.red_color[3:4]+ov.utils.red_color[2:3]+ov.utils.red_color[5:],
                color=['celltype'],show=False)
# Out:
# <AxesSubplot: title={'center': 'celltype'}, xlabel='X_mde_scVI1', ylabel='X_mde_scVI2'>

# %%
rb_rna
# Out:
# AnnData object with n_obs × n_vars = 729 × 16801
#     obs: 'tissue', 'domain', 'sample', 'nUMIs', 'mito_perc', 'detected_genes', 'cell_complexity', 'doublet_score', 'predicted_doublet', 'passing_mt', 'passing_nUMIs', 'passing_ngenes', 'n_genes', 'leiden', 'celltype', 'balancing_weight'
#     var: 'feature_types', 'mt', 'n_cells', 'percent_cells', 'robust', 'mean', 'var', 'residual_variances', 'highly_variable_features', 'chrom', 'chromStart', 'chromEnd', 'name', 'score', 'strand', 'thickStart', 'thickEnd', 'itemRgb', 'blockCount', 'blockSizes', 'blockStarts', 'gene_id', 'gene_type', 'dell', 'highly_variable'
#     uns: 'celltype_colors', 'leiden_colors', 'neighbors', 'leiden', 'paga', 'leiden_sizes', 'umap', 'dendrogram_leiden'
#     obsm: 'X_glue', 'X_mde_pca', 'X_mde_scVI', 'X_scVI', 'X_umap', 'scaled|original|X_pca'
#     varm: 'scaled|original|pca_loadings'
#     layers: 'counts', 'lognorm', 'scaled'
#     obsp: 'distances', 'connectivities'

# %%
pd.DataFrame(motif_rb2.uns['rank_genes_groups']['names']).head(50)
# Out:
#                       Cone              Cone-tumor                      P-p
# 0           MA0846.1.FOXC2          MA0131.2.HINFP  MA1642.1.NEUROG2(var.2)
# 1           MA1513.1.KLF15           MA0506.1.NRF1         MA1109.1.NEUROD1
# 2   MA0813.1.TFAP2B(var.3)          MA0647.1.GRHL1      MA0091.1.TAL1::TCF3
# 3           MA0032.2.FOXC1         MA1650.1.ZBTB14           MA1618.1.Ptf1a
# 4           MA0851.1.Foxj3          MA1122.1.TFDP1         MA0669.1.NEUROG2
# 5            MA0506.1.NRF1           MA0139.1.CTCF           MA1638.1.HAND2
# 6           MA1471.1.BARX2          MA1513.1.KLF15    MA1568.1.TCF21(var.2)
# 7   MA0815.1.TFAP2C(var.3)           MA0471.2.E2F6            MA1604.1.Ebf2
# 8           MA0052.4.MEF2A           MA0162.4.EGR1         MA0668.1.NEUROD2
# 9           MA0131.2.HINFP          MA0632.2.TCFL5           MA1468.1.ATOH7
# 10         MA1650.1.ZBTB14           MA1584.1.ZIC5    MA1467.1.ATOH1(var.2)
# 11         MA0629.1.Rhox11         MA1569.1.TFAP2E             MA0648.1.GSC
# 12          MA0740.1.KLF14           MA1419.1.IRF4            MA1637.1.EBF3
# 13          MA1607.1.Foxl2          MA1102.2.CTCFL          MA1123.2.TWIST1
# 14          MA1102.2.CTCFL          MA0157.2.FOXO3           MA0461.2.Atoh1
# 15          MA0845.1.FOXB1          MA0031.1.FOXD1             MA0083.3.SRF
# 16           MA1584.1.ZIC5  MA0815.1.TFAP2C(var.3)  MA1472.1.BHLHA15(var.2)
# 17           MA1516.1.KLF3           MA0696.1.ZIC1            MA0056.2.MZF1
# 18           MA1418.1.IRF3  MA0813.1.TFAP2B(var.3)         MA0623.2.NEUROG1
# 19         MA0811.1.TFAP2B           MA0733.1.EGR4            MA0154.4.EBF1
# 20          MA0497.1.MEF2C  MA0872.1.TFAP2A(var.3)           MA0714.1.PITX3
# 21          MA0773.1.MEF2D           MA0697.1.ZIC3            MA0891.1.GSC2
# 22         MA0787.1.POU3F2          MA0740.1.KLF14          MA0633.1.Twist2
# 23         MA1653.1.ZNF148          MA1471.1.BARX2            MA1480.1.DPRX
# 24  MA0872.1.TFAP2A(var.3)          MA0619.1.LIN54           MA0826.1.OLIG1
# 25          MA0637.1.CENPB            MA1564.1.SP9           MA1524.1.MSGN1
# 26         MA0901.2.HOXB13         MA1125.1.ZNF384         MA0818.1.BHLHE22
# 27           MA0738.1.HIC2          MA1607.1.Foxl2    MA1570.1.TFAP4(var.2)
# 28          MA1623.1.Stat2           MA0652.1.IRF8           MA0478.1.FOSL2
# 29           MA1515.1.KLF2          MA0032.2.FOXC1            MA0060.3.NFYA
# 30          MA0030.1.FOXF2  MA0810.1.TFAP2A(var.2)           MA1547.1.PITX2
# 31          MA0847.2.FOXD2         MA0901.2.HOXB13     MA1142.1.FOSL1::JUND
# 32        MA0679.2.ONECUT1         MA0527.1.ZBTB33           MA0796.1.TGIF1
# 33            MA0084.1.SRY         MA1657.1.ZNF652            MA0502.2.NFYB
# 34          MA0613.1.FOXG1           MA0751.1.ZIC4     MA1138.1.FOSL2::JUNB
# 35          MA0614.1.Foxj2          MA0145.3.TFCP2       MA1134.1.FOS::JUNB
# 36  MA0810.1.TFAP2A(var.2)           MA0472.2.EGR2           MA0682.2.PITX1
# 37          MA1487.1.FOXE1         MA0750.2.ZBTB7A     MA1144.1.FOSL2::JUND
# 38           MA0050.2.IRF1          MA1463.1.ARGFX           MA0832.1.Tcf21
# 39           MA1517.1.KLF6          MA0497.1.MEF2C           MA1101.2.BACH2
# 40           MA0470.2.E2F4         MA1580.1.ZBTB32        MA0099.3.FOS::JUN
# 41          MA1152.1.SOX15            MA0746.2.SP3      MA1130.1.FOSL2::JUN
# 42         MA0785.1.POU2F1          MA0033.2.FOXL1            MA0712.2.OTX2
# 43           MA0162.4.EGR1          MA0042.2.FOXI1             MA0476.1.FOS
# 44        MA0757.1.ONECUT3          MA0848.1.FOXO4       MA1141.1.FOS::JUND
# 45           MA0652.1.IRF8          MA0849.1.FOXO6     MA1137.1.FOSL1::JUNB
# 46         MA1125.1.ZNF384          MA0850.1.FOXP3      MA1135.1.FOSB::JUNB
# 47         MA0791.1.POU4F3           MA0653.1.IRF9     MA0860.1.Rarg(var.2)
# 48         MA0789.1.POU3F4           MA0772.1.IRF7          MA1485.1.FERD3L
# 49          MA1606.1.Foxf1          MA0025.2.NFIL3           MA0678.1.OLIG2

# %% [markdown]
# ## P-p

# %%
ov.utils.embedding(motif_rb,
                basis='X_mde_lsi',frameon='small',palette=ov.utils.orange_color[5:6]+ov.utils.orange_color[0:1]+ov.utils.orange_color[7:8]+ov.utils.orange_color[9:10]+ov.utils.orange_color[6:7]+ov.utils.red_color[:1]+ov.utils.red_color[1:2]+ov.utils.red_color[3:4]+ov.utils.red_color[2:3]+ov.utils.red_color[5:],
                color=['MA0154.4.EBF1'],show=False,vmax=3.5,vmin=-1)
# Out:
# <AxesSubplot: title={'center': 'MA0154.4.EBF1'}, xlabel='X_mde_lsi1', ylabel='X_mde_lsi2'>

# %%
gene='EBF1'
sc.pl.embedding(
        rb_rna,
        basis="X_mde_scVI",
        color=[gene],
        title='EBF1',
        frameon=False,
        ncols=3,
        #return_fig=True,
        wspace=0.5,
        show=False,
        cmap="PRGn_r",
        vmin=-1,
        vmax=4,
        #palette=sc_color[11:],
    )
# Out:
# <AxesSubplot: title={'center': 'EBF1'}, xlabel='X_mde_scVI1', ylabel='X_mde_scVI2'>

# %% [markdown]
# ## Cone

# %%
ov.utils.embedding(motif_rb,
                basis='X_mde_lsi',frameon='small',palette=ov.utils.orange_color[5:6]+ov.utils.orange_color[0:1]+ov.utils.orange_color[7:8]+ov.utils.orange_color[9:10]+ov.utils.orange_color[6:7]+ov.utils.red_color[:1]+ov.utils.red_color[1:2]+ov.utils.red_color[3:4]+ov.utils.red_color[2:3]+ov.utils.red_color[5:],
                color=['MA1152.1.SOX15'],show=False,vmax=1.5,vmin=-1.5)
# Out:
# <AxesSubplot: title={'center': 'MA1152.1.SOX15'}, xlabel='X_mde_lsi1', ylabel='X_mde_lsi2'>

# %%
gene='SOX15'
sc.pl.embedding(
        rb_rna,
        basis="X_mde_scVI",
        color=[gene],
        title='SOX15',
        frameon=False,
        ncols=3,
        #return_fig=True,
        wspace=0.5,
        show=False,
        cmap="PRGn_r",
        vmin=-1,
        vmax=4.5,
        #palette=sc_color[11:],
    )
# Out:
# <AxesSubplot: title={'center': 'SOX15'}, xlabel='X_mde_scVI1', ylabel='X_mde_scVI2'>

# %% [markdown]
# ## Cone-tumor

# %%
ov.utils.embedding(motif_rb,
                basis='X_mde_lsi',frameon='small',palette=ov.utils.orange_color[5:6]+ov.utils.orange_color[0:1]+ov.utils.orange_color[7:8]+ov.utils.orange_color[9:10]+ov.utils.orange_color[6:7]+ov.utils.red_color[:1]+ov.utils.red_color[1:2]+ov.utils.red_color[3:4]+ov.utils.red_color[2:3]+ov.utils.red_color[5:],
                color=['MA0025.2.NFIL3'],show=False,vmax=2.5,vmin=-2)
# Out:
# <AxesSubplot: title={'center': 'MA0025.2.NFIL3'}, xlabel='X_mde_lsi1', ylabel='X_mde_lsi2'>

# %%
gene='NFIL3'
sc.pl.embedding(
        rb_rna,
        basis="X_mde_scVI",
        color=[gene],
        title='NFIL3',
        frameon=False,
        ncols=3,
        #return_fig=True,
        wspace=0.5,
        show=False,
        cmap="PRGn_r",
        vmin=-1,
        vmax=5,
        #palette=sc_color[11:],
    )
# Out:
# <AxesSubplot: title={'center': 'NFIL3'}, xlabel='X_mde_scVI1', ylabel='X_mde_scVI2'>

# %% [markdown]
# ## 开放

# %%
import Epiverse as ev

# %%
rb_atac
# Out:
# AnnData object with n_obs × n_vars = 729 × 150000
#     obs: 'sample', 'tissue', 'domain', 'week', 'balancing_weight', 'celltype'
#     var: 'chrom', 'chromStart', 'chromEnd', 'highly_variable', 'seqnames', 'start', 'end'
#     uns: 'celltype_colors'
#     obsm: 'X_glue', 'X_lsi', 'X_mde_lsi', 'X_umap'

# %%
# Get chromosome sizes (for hg38 here)
import pyranges as pr
import requests
import pandas as pd
target_url = '/mnt/home/yihanzhao/RB/data_new/hg38.chrom.sizes'
chromsizes=pd.read_csv(target_url, sep='\t', header=None)
chromsizes.columns=['Chromosome', 'End']
chromsizes['Start']=[0]*chromsizes.shape[0]
chromsizes=chromsizes.loc[:,['Chromosome', 'Start', 'End']]
# Exceptionally in this case, to agree with CellRangerARC annotations
chromsizes['Chromosome'] = [chromsizes['Chromosome'][x].replace('v', '.') for x in range(len(chromsizes['Chromosome']))]
chromsizes['Chromosome'] = [chromsizes['Chromosome'][x].split('_')[1] if len(chromsizes['Chromosome'][x].split('_')) > 1 else chromsizes['Chromosome'][x] for x in range(len(chromsizes['Chromosome']))]
chromsizes=pr.PyRanges(chromsizes)

# %%
rb_atac.obs['celltype'].cat.categories.tolist()
# Out:
# ['CPC', 'Cone', 'Cone-tumor', 'Middle', 'P-p', 'RSC', 'Rod', 'Rod pre', 'TCR']

# %%
#!mkdir result/pseudobulk_bw_files
ev.single.pseudobulk(rb_atac,chromsizes,cluster_key='celltype',size=1000,
           clusters=rb_atac.obs['celltype'].cat.categories.tolist(),
           chr=['seqnames','start','end'],
           bigwig_path='temp')
# Out:
# ['CPC', 'Cone', 'Cone-tumor', 'Middle', 'P-p', 'RSC', 'Rod', 'Rod pre', 'TCR']
#   0%|                                                                    | 0/9 [00:00<?, ?it/s]
# CPC chr_value
# CPC chr_start
# CPC chr_end
# CPC Name
# CPC Score
# CPC write
#  11%|██████▋                                                     | 1/9 [00:07<01:00,  7.56s/it]
# Cone chr_value
# Cone chr_start
# Cone chr_end
# Cone Name
# Cone Score
# Cone write
#  22%|█████████████▎                                              | 2/9 [00:11<00:39,  5.60s/it]
# Cone-tumor chr_value
# Cone-tumor chr_start
# Cone-tumor chr_end
# Cone-tumor Name
# Cone-tumor Score
# Cone-tumor write
#  33%|████████████████████                                        | 3/9 [00:16<00:32,  5.38s/it]
# Middle chr_value
# Middle chr_start
# Middle chr_end
# Middle Name
# Middle Score
# Middle write
#  44%|██████████████████████████▋                                 | 4/9 [00:22<00:26,  5.38s/it]
# P-p chr_value
# P-p chr_start
# P-p chr_end
# P-p Name
# P-p Score
# P-p write
#  56%|█████████████████████████████████▎                          | 5/9 [00:38<00:36,  9.12s/it]
# RSC chr_value
# RSC chr_start
# RSC chr_end
# RSC Name
# RSC Score
# RSC write
#  67%|████████████████████████████████████████                    | 6/9 [01:00<00:40, 13.55s/it]
# Rod chr_value
# Rod chr_start
# Rod chr_end
# Rod Name
# Rod Score
# Rod write
#  78%|██████████████████████████████████████████████▋             | 7/9 [01:05<00:21, 10.83s/it]
# Rod pre chr_value
# Rod pre chr_start
# Rod pre chr_end
# Rod pre Name
# Rod pre Score
# Rod pre write
#  89%|█████████████████████████████████████████████████████▎      | 8/9 [01:16<00:10, 10.97s/it]
# TCR chr_value
# TCR chr_start
# TCR chr_end
# TCR Name
# TCR Score
# TCR write
# 100%|████████████████████████████████████████████████████████████| 9/9 [01:19<00:00,  8.83s/it]

# %%
bw_dict=dict(zip(rb_atac.obs['celltype'].cat.categories.tolist(),
                 [f'temp/{i}.bw' for i in rb_atac.obs['celltype'].cat.categories]))
bw_obj=ev.bulk.bigwig(bw_dict)
bw_obj.read()
# Out:
# ......Loading CPC
# ......Loading Cone
# ......Loading Cone-tumor
# ......Loading Middle
# ......Loading P-p
# ......Loading RSC
# ......Loading Rod
# ......Loading Rod pre
# ......Loading TCR

# %%
bw_obj.load_gtf('/mnt/home/zehuazeng/data/gtf/gencode.v43.basic.annotation.gtf')
# Out:
# ......Loading gtf file

# %%
color_dict=dict(zip(rb_atac.obs['celltype'].cat.categories,rb_atac.uns['celltype_colors']))

# %% [markdown]
# ## P-p

# %%
rna.var.loc['EBF1',['chrom','chromStart','chromEnd']]
# Out:
# chrom              chr5
# chromStart    158695919
# chromEnd      159099916
# Name: EBF1, dtype: object

# %%
region_dict={
    'region1':[158695919, 159099916],
}

# %%
import matplotlib.pyplot as plt
#TCF4: chr18：55,222,185-55,635,957
fig,axes=bw_obj.plot_track(chrom='chr5',chromstart=158695000-50000,chromend=159099000+50000,
                  plot_names=rb_atac.obs['celltype'].cat.categories.tolist(),
                           transform='log1p',
                           gtf_color='#000000',
                figwidth=4,figheight=8.0,
                  color_dict=color_dict,
                  region_dict=region_dict,
                  jump_symbols=['ENSG','LINC'],prefered_name='gene_name',
                           ymax=3,text_fontsize=10
                 )

# %% [markdown]
# ## Cone

# %%
rna.var.loc['SOX15',['chrom','chromStart','chromEnd']]
# Out:
# chrom           chr17
# chromStart    7588177
# chromEnd      7590094
# Name: SOX15, dtype: object

# %%
region_dict={
    'region1':[7588177, 7590094],
}

# %%
import matplotlib.pyplot as plt
fig,axes=bw_obj.plot_track(chrom='chr17',chromstart=7588000-5000,chromend=7590000+5000,
                  plot_names=rb_atac.obs['celltype'].cat.categories.tolist(),
                           transform='log1p',
                           gtf_color='#000000',
                figwidth=4,figheight=8.0,
                  color_dict=color_dict,
                  region_dict=region_dict,
                  jump_symbols=['ENSG','LINC'],prefered_name='gene_name',
                           ymax=2,text_fontsize=10
                 )

# %% [markdown]
# ## Cone-tumor

# %%
rna.var.loc['NFIL3',['chrom','chromStart','chromEnd']]
# Out:
# chrom             chr9
# chromStart    91409044
# chromEnd      91423832
# Name: NFIL3, dtype: object

# %%
region_dict={
    'region1':[91409044, 91423832],
}

# %%
import matplotlib.pyplot as plt
fig,axes=bw_obj.plot_track(chrom='chr9',chromstart=91409000-10000,chromend=91423000+10000,
                  plot_names=rb_atac.obs['celltype'].cat.categories.tolist(),
                           transform='log1p',
                           gtf_color='#000000',
                figwidth=4,figheight=8.0,
                  color_dict=color_dict,
                  region_dict=region_dict,
                  jump_symbols=['ENSG','LINC'],prefered_name='gene_name',
                           ymax=0.8,text_fontsize=10
                 )

# %% [markdown]
# ## SIMBA

# %%
import pandas as pd

# %%
dict_tf_targets = pd.read_csv("/mnt/home/yihanzhao/RB/data_new/TF-gene/EBF1.csv")

# %%
dict_tf_targets
# Out:
#      Unnamed: 0  celltype id_dataset entity_anno  distance  query
# 0         SRPK3       NaN    query_0        gene  0.099387      0
# 1           RHO       NaN    query_0        gene  0.103373      0
# 2     LINC02115       NaN    query_0        gene  0.106614      0
# 3         SAMD7       NaN    query_0        gene  0.107240      0
# 4         GNGT1       NaN    query_0        gene  0.110396      0
# ..          ...       ...        ...         ...       ...    ...
# 95  TMEM108-AS1       NaN    query_0        gene  0.241997      0
# 96     MAP1LC3A       NaN    query_0        gene  0.242590      0
# 97       WNT10A       NaN    query_0        gene  0.245624      0
# 98        FRAT2       NaN    query_0        gene  0.246891      0
# 99        MUC5B       NaN    query_0        gene  0.247574      0
#
# [100 rows x 6 columns]

# %%
import networkx as nx
G = nx.Graph()
#herb_jvhua=herb       
for i in ['SRPK3','RHO','LINC02115','SAMD7','GNGT1']:
    G.add_edge('P-p',i)
    for j in dict_tf_targets.index.tolist():
        G.add_edge(i,j)

# %%
rb_atac=sc.read_h5ad('/mnt/home/yihanzhao/RB/data_new/rb_atac.h5ad')

# %%
color_dict=dict(zip(rb_atac.obs['celltype'].cat.categories,rb_atac.uns['celltype_colors']))
#color_dict['gene']='#3b9868'
color_dict['gene']='#c2c2c2'

# %%
p=dict(G.nodes)

# %%
color_li=[]

for i in p.keys():
    if i in ['SRPK3','RHO','LINC02115','SAMD7','GNGT1','P-p']:
        color_li.append(color_dict['P-p'])
        #print(i)
    else:
        color_li.append(color_dict['gene'])

# %%
rank_gene=[]
for i in ['SRPK3','RHO','LINC02115','SAMD7','GNGT1']:
    rank_gene+=dict_tf_targets.index.tolist()[:10]

# %%
import matplotlib.patches as mpatches
from adjustText import adjust_text
fig, ax = plt.subplots(figsize=(6,4))
pos = nx.spring_layout(G, scale=1, k=0.01)
fig, ax = plt.subplots()
nx.draw_networkx_edges(G, pos, nodelist=list(p.keys()), alpha=0.4,edge_color='#c2c2c2')
degree_dict = dict(G.degree(G.nodes()))
sorted(degree_dict.items(),key=lambda x: x[1],reverse=True)
nx.draw_networkx_nodes(
    G,
    pos,
    nodelist=list(p.keys()),
    node_size=[degree_dict[v]*20 for v in G],
    node_color=color_li,
    #cmap=c,
    alpha=0.6,
    linewidths=1,
)
hub_gene=['SRPK3','RHO','LINC02115','SAMD7','GNGT1']+rank_gene
pos1 = {i: pos[i] for i in hub_gene if i in pos and isinstance(pos[i], (list, tuple)) and len(pos[i]) == 2}
for i in hub_gene:
    pos1[i]=pos[i]

fig, ax = plt.subplots()
texts = [ax.text(pos1[i][0], 
                 pos1[i][1],
                 i,
                 fontdict={'size': 10, 'weight': 'bold', 'color': 'black'}
                 ) for i in hub_gene if i in pos1]

adjust_text(texts,only_move={"text": "xy", "static": "xy", "explode": "xy", "pull": "xy"},
                    arrowprops=dict(arrowstyle='-', color='black'))


ax.axis("off")
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
# 计算节点度数


# 绘制网络节点
nx.draw_networkx_nodes(
    G,
    pos,
    node_size=[degree_dict[v] * 20 for v in G],
    node_color='blue',  # 示例颜色
    alpha=0.6,
    linewidths=1,
)

# 关键基因
hub_gene = ['SRPK3', 'RHO', 'LINC02115', 'SAMD7', 'GNGT1']  # 示例基因名
rank_gene = []  # 你可以在这里添加更多基因名
hub_gene += rank_gene

# 确保pos1中的所有值都是有效的坐标对
pos1 = {i: pos[i] for i in hub_gene if i in pos and isinstance(pos[i], (list, tuple)) and len(pos[i]) == 2}

# 调整文本位置
fig, ax = plt.subplots()
texts = [ax.text(pos1[i][0], 
                 pos1[i][1],
                 i,
                 fontdict={'size': 10, 'weight': 'bold', 'color': 'black'}
                 ) for i in hub_gene if i in pos1]

adjust_text(texts, only_move={"text": "xy", "static": "xy", "explode": "xy", "pull": "xy"},
                    arrowprops=dict(arrowstyle='-', color='black'))

ax.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_884020/3874505158.py in <cell line: 44>()
#      42                  ) for i in hub_gene if i in pos1]
#      43
# ---> 44 adjust_text(texts, only_move={"text": "xy", "static": "xy", "explode": "xy", "pull": "xy"},
#      45                     arrowprops=dict(arrowstyle='-', color='black'))
#      46
#
# /mnt/data/env/pyomic/lib/python3.8/site-packages/adjustText/__init__.py in adjust_text(texts, x, y, add_objects, ax, expand_text, expand_points, expand_objects, expand_align, autoalign, va, ha, force_text, force_points, force_objects, lim, precision, only_move, avoid_text, avoid_points, avoid_self, save_steps, save_prefix, save_format, add_step_numbers, *args, **kwargs)
#     565     ax = ax or plt.gca()
#     566     r = get_renderer(ax.get_figure())
# --> 567     transform = texts[0].get_transform()
#     568     if (x is not None) & (y is not None):
#     569         for ix, tupxy in enumerate(zip(x, y)):
#
# IndexError: list index out of range

# %%
gene_list=['FAA4','POX1','FAT1','FAS2','FAS1','FAA1','OLE1','YJU3','TGL3','INA1','TGL5']

# %%
gene_type_dict=dict(zip(gene_list,['Type1']*5+['Type2']*6))
gene_color_dict=dict(zip(gene_list,['#F7828A']*5+['#9CCCA4']*6))

# %%
ppi=ov.bulk.pyPPI(gene=gene_list,
                      gene_type_dict=gene_type_dict,
                      gene_color_dict=gene_color_dict,
                      species=4932)

# %%
ppi.interaction_analysis()
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# /mnt/data/env/pyomic/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# /mnt/data/env/pyomic/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      71
# ---> 72     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73         af, socktype, proto, canonname, sa = res
#
# /mnt/data/env/pyomic/lib/python3.8/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     917     addrlist = []
# --> 918     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     919         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno -3] Temporary failure in name resolution
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# /mnt/data/env/pyomic/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#
# /mnt/data/env/pyomic/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385         try:
# --> 386             self._validate_conn(conn)
#     387         except (SocketTimeout, BaseSSLError) as e:
#
# /mnt/data/env/pyomic/lib/python3.8/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1039         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1040             conn.connect()
#    1041
#
# /mnt/data/env/pyomic/lib/python3.8/site-packages/urllib3/connection.py in connect(self)
#     357         # Add certificate verification
# --> 358         self.sock = conn = self._new_conn()
#     359         hostname = self.host
#
# /mnt/data/env/pyomic/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     185         except SocketError as e:
# --> 186             raise NewConnectionError(
#     187                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x7f2f99b4d370>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# /mnt/data/env/pyomic/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     488             if not chunked:
# --> 489                 resp = conn.urlopen(
#     490                     method=request.method,
#
# /mnt/data/env/pyomic/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     784
# --> 785             retries = retries.increment(
#     786                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# /mnt/data/env/pyomic/lib/python3.8/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     591         if new_retry.is_exhausted():
# --> 592             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     593
#
# MaxRetryError: HTTPSConnectionPool(host='string-db.org', port=443): Max retries exceeded with url: /api/tsv-no-header/network (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f2f99b4d370>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# /tmp/ipykernel_884020/2286802591.py in <cell line: 1>()
# ----> 1 ppi.interaction_analysis()
#
# /mnt/data/env/pyomic/lib/python3.8/site-packages/omicverse/bulk/_network.py in interaction_analysis(self)
#     159             G: the networkx object of PPI in query gene list
#     160         """
# --> 161         G=generate_G(self.gene,
#     162                           self.species,
#     163                           self.score)
#
# /mnt/data/env/pyomic/lib/python3.8/site-packages/omicverse/bulk/_network.py in generate_G(gene, species, score)
#     120     """
#     121
# --> 122     a=string_interaction(gene,species)
#     123     b=a.drop_duplicates()
#     124     b.head()
#
# /mnt/data/env/pyomic/lib/python3.8/site-packages/omicverse/bulk/_network.py in string_interaction(gene, species)
#      33
#      34     }
# ---> 35     response = requests.post(request_url, data=params)
#      36     res=pd.DataFrame()
#      37     res['stringId_A']=[j.strip().split("\t")[0] for j in response.text.strip().split("\n")]
#
# /mnt/data/env/pyomic/lib/python3.8/site-packages/requests/api.py in post(url, data, json, **kwargs)
#     113     """
#     114
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#     116
#     117
#
# /mnt/data/env/pyomic/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# /mnt/data/env/pyomic/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     585         }
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#     589         return resp
#
# /mnt/data/env/pyomic/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     699
#     700         # Send the request
# --> 701         r = adapter.send(request, **kwargs)
#     702
#     703         # Total elapsed time of the request (approximately)
#
# /mnt/data/env/pyomic/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     563                 raise SSLError(e, request=request)
#     564
# --> 565             raise ConnectionError(e, request=request)
#     566
#     567         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='string-db.org', port=443): Max retries exceeded with url: /api/tsv-no-header/network (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f2f99b4d370>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution'))

# %%
ppi.plot_network()

# %% [markdown]
# ## 韦恩图

# %%
motif.var['gene']=motif.var.index

# %%
motif.var
# Out:
#                                gene
# MA0004.1.Arnt                  ARNT
# MA0006.1.Ahr::Arnt        AHR::ARNT
# MA0019.1.Ddit3::Cebpa  DDIT3::CEBPA
# MA0029.1.Mecom                MECOM
# MA0030.1.FOXF2                FOXF2
# ...                             ...
# MA0093.3.USF1                  USF1
# MA0526.3.USF2                  USF2
# MA0748.2.YY2                    YY2
# MA0528.2.ZNF263              ZNF263
# MA0609.2.CREM                  CREM
#
# [746 rows x 1 columns]

# %%
motif.var['gene'] = motif.var['gene'].str.split('.').str[-1].str.upper()

# %%
ret_motif=list(motif.var['gene'])
ret_motif

# %%
ret_gene=list(rna.var.index)
ret_gene

# %%
set_motif = set(ret_motif)
set_gene = set(ret_gene)

# %%
# 计算交集
intersection = set_motif & set_gene

# 计算每个集合的大小和交集的大小
size_motif = len(set_motif)
size_gene = len(set_gene)
size_intersection = len(intersection)

# 创建Venn图
plt.figure(figsize=(8, 8))

# 绘制Venn图
v = venn2(subsets=(size_motif, size_gene, size_intersection), 
          set_labels=('TF', 'gene'),
          set_colors=(ov.pl.red_color[1],ov.pl.green_color[1]))

# 绘制Venn图外框
venn2_circles(subsets=(size_motif, size_gene, size_intersection),
              linestyle='--', linewidth=2, color="black")
# Out:
# [<matplotlib.patches.Circle at 0x7f3063797850>,
#  <matplotlib.patches.Circle at 0x7f3063797910>]

# %% [markdown]
# ## EBF1-GSEA

# %%
import pandas as pd

# %%
df = pd.read_csv('/mnt/home/yihanzhao/RB/data_new/TF-gene/TF_EBF1_target_genes(1).csv')

# %%
df['target_genes']
# Out:
# 0     PNPLA7
# 1    SLC18A3
# 2      FEM1A
# 3       DMPK
# 4       OASL
# 5      FMNL1
# Name: target_genes, dtype: object

# %%
gene_list=['PNPLA7','SLC18A3','FEM1A','DMPK','OASL','FMNL1','CENPF','GTSE1']

# %%
enr=ov.bulk.geneset_enrichment(gene_list=gene_list,
                                pathways_dict=pathway_dict,
                                pvalue_type='normal',
                                organism='human')

# %%
pathway_dict=ov.utils.geneset_prepare('/mnt/home/zehuazeng/analysis/placenta/genesets/WikiPathway_2021_Human.txt',organism='Human')

# %%
ax=ov.bulk.geneset_plot(enr,figsize=(2,4),fig_title='Wiki Pathway 2021',
                    cax_loc=[2, 0.45, 0.5, 0.02],
                    bbox_to_anchor_used=(-0.25, -13),node_diameter=10,
                    cmap='Greens',custom_ticks=[3,5])
plt.grid(False)

# %% [markdown]
# ## SOX15-GSEA

# %%
df2 = pd.read_csv('/mnt/home/yihanzhao/RB/data_new/TF-gene/TF_SOX15_target_genes(1).csv')

# %%
enr=ov.bulk.geneset_enrichment(gene_list=list(df2['target_genes']),
                                pathways_dict=pathway_dict,
                                pvalue_type='normal',
                                organism='human')

# %%
ax=ov.bulk.geneset_plot(enr,figsize=(2,5.5),fig_title='SOX15-Wiki Pathway 2021',
                    cax_loc=[2, 0.45, 0.5, 0.02],
                    bbox_to_anchor_used=(-0.25, -13),node_diameter=15,
                    cmap='Reds',custom_ticks=[5,8])
plt.grid(False)

# %% [markdown]
# ## NFIL3-GSEA

# %%
df3 = pd.read_csv('/mnt/home/yihanzhao/RB/data_new/TF-gene/TF_NFIL3_target_genes(1).csv')

# %%
enr=ov.bulk.geneset_enrichment(gene_list=list(df3['target_genes']),
                                pathways_dict=pathway_dict,
                                pvalue_type='normal',
                                organism='human')

# %%
ax=ov.bulk.geneset_plot(enr,figsize=(2,5.5),fig_title='NFIL3-Wiki Pathway 2021',
                    cax_loc=[2, 0.45, 0.5, 0.02],
                    bbox_to_anchor_used=(-0.25, -13),node_diameter=15,
                    cmap='Reds',custom_ticks=[4,6])
plt.grid(False)
